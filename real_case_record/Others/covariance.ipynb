# %%
a = rnorm(50)*10
b = a*-0.05 + rnorm(50)*5

# %%
a
# Out:
#  [1] -18.5849876 -12.0815891  -0.3554367  -8.4806929 -13.2896254 -14.7391736
#  [7]  20.2817976   5.0892471   5.4015385  10.6177608  -2.7871077   1.4285961
# [13]   5.5974267  -7.3505272  -7.7222289   6.2741453 -10.3989649  -1.2497885
# [19]  -5.4456493 -15.7431223   5.4700435  17.9549629  -0.4665365   5.6124143
# [25]  -4.7197317   6.2112576 -10.6286135  -1.4064937  -7.9773433  -4.4269719
# [31]  11.2999852 -11.1760249  -1.3699787  -3.8001885   6.2114713  21.9990195
# [37]  -6.8460038  11.4068204   8.7841884   7.8817512   9.3674183  -8.8865064
# [43]  11.8861306 -12.2715571 -10.7012559  11.7611978   5.1655773  -2.0901283
# [49]  -3.3895409   1.7187646

# %%
m = matrix(c(a,b),ncol=2)

# %%
m1 = m1 - colMeans(m1)

# %%
cov(m1)
# Out:
#      [,1]      [,2]
# [1,] 94.311375 -1.664737
# [2,] -1.664737 20.408082

# %%
t(m1)%*%m1/(nrow(m1)-1)
# Out:
#      [,1]      [,2]
# [1,] 94.312032 -1.665394
# [2,] -1.665394 20.408739
